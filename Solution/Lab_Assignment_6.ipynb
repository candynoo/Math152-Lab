# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric,plot3d_parametric_surface, plot3d_parametric_line,plot3d)

# %%
s,t=symbols('s t',positive=True) 
f=t
F=integrate(f*exp(-s*t),(t,0,oo)) 
print('The Laplace Transform of t is',F)
# Out:
# The Laplace Transform of t is s**(-2)

# %%
print("Problem1")
t = symbols('t')
s = symbols('s', positive=True)
for i in range(1,5):
    f = t**(i)
    print(integrate(f*exp(-s*t),(t,0,oo)))
print("The general form is n!/s**(i+1)")
print("The indicated result for t**10 should be 10!/s**11")
print(integrate(t**10 *exp(-s*t),(t,0,oo)),"satifies general form")
# Out:
# Problem1
# s**(-2)
# 2/s**3
# 6/s**4
# 24/s**5
# The general form is n!/s**(i+1)
# The indicated result for t**10 should be 10!/s**11
# 3628800/s**11 satifies general form

# %%
matplotlib notebook

# %%
print("Problem2")
print("part(a)")
for i in range(1,11):
    print(atan(ln(i)).evalf())
print("guessed value of limit is 1.20")

print("part(b)")    
import matplotlib.pyplot as plt
listplot = [atan(ln(i)) for i in range(1,51)]
plt.plot(listplot,'o')
print("guessed value of limit is 1.36")

print("part(c)")
n = symbols('n')
an = atan(ln(n))
L = limit(an,n, oo)
print(L)
print(L.evalf())
# Out:
# Problem2
# part(a)
# 0
# 0.606111934732855
# 0.832352909060798
# 0.945886379973496
# 1.01483690649416
# 1.06174748050213
# 1.09609196520771
# 1.12254648161274
# 1.14369309269278
# 1.16107958268582
# guessed value of limit is 1.20
# part(b)
# guessed value of limit is 1.36
# part(c)
# pi/2
# 1.57079632679490

# %%
print("Problem3")
print("Part(a)")
a=1
P = 64
for i in range(1,11):
    print(a)
    a = P/(3*a**2)+2*a/3
print("limit may be 4")

print("part(b)")
a=1
P = 216
for i in range(1,11):
    print(a)
    a = P/(3*a**2)+2*a/3
print("limit may be 6")

print("part(c)")
a=1
P = 27
for i in range(1,11):
    print(a)
    a = P/(3*a**2)+2*a/3
print("limit may be 3")

print("part(d)")
Q = symbols('Q')
L = symbols('L')
soln = solve(L-Q/(3*L**2)-2*L/3,Q)
print("Q=",soln)
# Out:
# Problem3
# Part(a)
# 1
# 22.0
# 14.710743801652892
# 9.905742680039774
# 6.821241015893387
# 5.005986187320336
# 4.188617836539221
# 4.008366165439264
# 4.000017449510739
# 4.000000000076121
# limit may be 4
# part(b)
# 1
# 72.66666666666667
# 48.458079660335365
# 32.336048413257366
# 21.626224274645974
# 14.571429800581024
# 10.053386822532781
# 7.414631307227974
# 6.252731892895682
# 6.0100776484658
# limit may be 6
# part(c)
# 1
# 9.666666666666666
# 6.540758356453956
# 4.570876778578707
# 3.478019233386796
# 3.0626891086275365
# 3.001274406506175
# 3.0000005410641766
# 3.0000000000000977
# 3.0
# limit may be 3
# part(d)
# Q= [L**3]

# %%
matplotlib notebook

# %%
print("Problem 4")
import matplotlib.pyplot as plt
from numpy import cumsum
print("part(a)")
n = symbols('n')
f = (9/10)**n /n
print(limit(f,n,oo))

print("part(b)")
nplot = [i for i in range(1,51)]
terms = [f.subs(n,i) for i in range(1,51)]
s=0
sums = cumsum(terms)
#print(sums)
plt.plot(nplot,terms,'ro',nplot,sums,'bo')

print("part(c)")
S = summation(f,(n,1,oo))
print(S)
# Out:
# Problem 4
# part(a)
# 0
# part(b)
# <img src="data:image/png;base64,..." width="640">
# part(c)
# 2.30258509299405
