# %% [markdown]
# ## Math 152 Lab - Assignment 6 ##

# %% [markdown]
# ## Section 529, 530, 540 ##

# %% [markdown]
# ### Jingya Yan ###
#
# Email: jingya.yan@math.tamu.edu
#
# Office Hour (for lab only): Wednesday 3-4pm (or by appointment)

# %% [markdown]
# ### 1. Assignment Instructions ###

# %% [markdown]
# http://calclab.math.tamu.edu/Python/LabSched152.html
#
# Make sure you are using the template given in the link.
#
# (open the course schedule page and right click on the template link and select "save as")
#
# Make sure you are using Python 3, the codes may not perform as expected in Python 2.
#
# Each team turns in one printed file at next week's lab.
#
# If your team size drops below 3, I will try combine your team with others.
# #### Assignment 5 will be due on Mar 16 (Monday after Spring Break). ####

# %% [markdown]
# ### 2. Overview ###
#
# http://calclab.math.tamu.edu/Python/Lab6_152Overview.pdf

# %% [markdown]
# ### 3. Some Useful Commands ###

# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric,plot3d_parametric_surface, plot3d_parametric_line,plot3d)

# %% [markdown]
# #### Define Symbols ####
#
# https://urldefense.proofpoint.com/v2/url?u=https-3A__docs.sympy.org_latest_tutorial_intro.html-23a-2Dmore-2Dinteresting-2Dexample&d=DwMFaQ&c=u6LDEWzohnDQ01ySGnxMzg&r=0S5Vp3YJyAl2qMyYOYqVE-tUOvBz75Wirkf-T3iD8UU&m=J5TIah_hJ8O3kmRX_Dx6jVouBmOQDR5ys2rnuGKsidY&s=67RRGhDkcSEJuyf79U5FQTe6FJWXmCHlkPp4aE5cUxk&e=

# %%
x = symbols('x')    # x will be a symbold
a,b,c,d = symbols('a,b,c,d')    # define multiple symbols at a time
y = symbols('y', positive=True) # define a positive symbol

# %% [markdown]
# #### Define a Function ####
#
# https://docs.sympy.org/latest/tutorial/intro.html#a-more-interesting-example

# %%
x = symbols('x')    # Define a symbol as variable or you'll receive error while running
f = exp(x)/ln(x)    # Define any function you want with x as variable
print("f=",f)
# Out:
# f= exp(x)/log(x)

# %% [markdown]
# #### Substitution ####
#
# https://docs.sympy.org/latest/tutorial/basic_operations.html#substitution

# %%
x = symbols('x')    # Define variable
f = x ** 3           # Define a function of x
f_2 = f.subs(x,2)   # Find the value of f when x=2
print(f_2)
# Out:
# 8

# %%
y = symbols('y')
f_y = f.subs(x,y)   # Substitude x by y
print(f_y)
# Out:
# y**3

# %%
a,b,c,d = symbols('a,b,c,d')
f = a+b+c+d
print(f.subs([(a,1),(b,2),(c,3),(d,4)]))    # Substitude multiple numbers at a time
# Out:
# 10

# %% [markdown]
# #### Integrate ####
#
# https://docs.sympy.org/latest/tutorial/calculus.html#integrals

# %%
x = symbols('x')
f = sin(x)
int_f = integrate(f,x)     # calculate indefinite integral
print("Integral of f(x) is:",int_f)
defint_f = integrate(f,(x,0,pi))      # calculate definite integral of f from 0 to pi
print("Integral of f(x) from 0 to pi is:",defint_f)
# Out:
# Integral of f(x) is: -cos(x)
# Integral of f(x) from 0 to pi is: 2

# %% [markdown]
# #### Evaluation of Number ####
#
# https://docs.sympy.org/latest/tutorial/basic_operations.html#evalf

# %%
a = sqrt(2)
print(a)               
print(a.evalf())    # Evaluate irrational number to its approaximated value
# Out:
# sqrt(2)
# 1.41421356237310

# %% [markdown]
# #### Simplify Formula ####

# %%
y = symbols('y')
g = sqrt(y)*(y - 1)**2/5 + sqrt(y)*(y - 1)/15 - 2*sqrt(y)/15
print(g)
print("g can be simplified to",simplify(g))
# Out:
# sqrt(y)*(y - 1)**2/5 + sqrt(y)*(y - 1)/15 - 2*sqrt(y)/15
# g can be simplified to y**(3/2)*(3*y - 5)/15

# %% [markdown]
# #### Solve a Function

# %% [markdown]
# https://urldefense.proofpoint.com/v2/url?u=https-3A__www.scipy-2Dlectures.org_advanced_sympy.html-23equation-2Dsolving&d=DwMFaQ&c=u6LDEWzohnDQ01ySGnxMzg&r=0S5Vp3YJyAl2qMyYOYqVE-tUOvBz75Wirkf-T3iD8UU&m=Sn1qufafjrrMZlobHkjlzHZVH-H4ACHov6DUFQqKles&s=gp9SMKC6yC0FcXljMzt7Zb4AhhoW30idadCAp4PKldY&e=

# %%
x = symbols('x')
f = x ** 2 + 3*x +2
x_soln = solve (f,x)    # solve f=0 with respect to x
print("The solution of f(x)=0 is ", x_soln)
# Out:
# The solution of f(x)=0 is  [-2, -1]

# %%
x , a = symbols('x , a')
f = x ** 3 
x0 = solve(f-a, x)    # solve f-a=0 with respect to x
print("The solution of f(x)=a is ", x0[0], ",", x0[1] , ",", x0[2])
# Out:
# The solution of f(x)=a is  a**(1/3) , -a**(1/3)/2 - sqrt(3)*I*a**(1/3)/2 , -a**(1/3)/2 + sqrt(3)*I*a**(1/3)/2

# %% [markdown]
# #### Limit ####
#
# https://docs.sympy.org/latest/tutorial/calculus.html#limits

# %%
x = symbols('x')
f = (x ** 2 -4)/(x-2)
x_2 = limit(f,x,2)        # Find the limits of f when x is approaching 2
print("The limit of f(x) near 2 is ", x_2)
# Out:
# The limit of f(x) near 2 is  4

# %% [markdown]
# #### Construct a Loop ####
#
# https://docs.python.org/3/tutorial/datastructures.html#list-comprehensions

# %%
x = symbols('x')
for i in range(1,6):            # index is 1,2,3,4,5
    f = x**i
    print(integrate(f,x))       # print the integration of x, x**2, x**3, x**4, x**5
# Out:
# x**2/2
# x**3/3
# x**4/4
# x**5/5
# x**6/6

# %% [markdown]
# #### Construct a list generated by some loop ####
#
# https://urldefense.proofpoint.com/v2/url?u=https-3A__docs.python.org_3_tutorial_datastructures.html-23list-2Dcomprehensions&d=DwMFaQ&c=u6LDEWzohnDQ01ySGnxMzg&r=0S5Vp3YJyAl2qMyYOYqVE-tUOvBz75Wirkf-T3iD8UU&m=8y9Tl5OKZ4VaYViUEvDW0squ0wP1w6fkjykKfN5QA6U&s=Agyr2iaAb3CvJue06-9uiwWOyL2xwCb4OIzMLEJ1yCM&e=

# %%
n = symbols('n')
a_n = ln(n)
alist = [a_n.subs(n,i).evalf() for i in range(1,11)]    # create a list that contains for 10 terms
print(alist)
# Out:
# [0, 0.693147180559945, 1.09861228866811, 1.38629436111989, 1.60943791243410, 1.79175946922805, 1.94591014905531, 2.07944154167984, 2.19722457733622, 2.30258509299405]

# %% [markdown]
# #### Plot (numeric) ####
#
# Plotting a list of points.
#
# https://urldefense.proofpoint.com/v2/url?u=https-3A__matplotlib.org_tutorials_introductory_pyplot.html&d=DwMFaQ&c=u6LDEWzohnDQ01ySGnxMzg&r=0S5Vp3YJyAl2qMyYOYqVE-tUOvBz75Wirkf-T3iD8UU&m=8y9Tl5OKZ4VaYViUEvDW0squ0wP1w6fkjykKfN5QA6U&s=VRkI6hw3slVBUdqF7mMak0LtwERr7T2vKwM15XNWVMM&e=
#
# #### for every new graph, you need to type a new 'matplotlib notebook'

# %%
matplotlib notebook

# %%
import matplotlib.pyplot as plt      # you need to import this command first 
n = symbols('n')
a_n = ln(n)
alist = [a_n.subs(n,i) for i in range(1,101)]
plt.plot(alist,'o')                  # plot alist with dots
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
matplotlib notebook

# %%
b_n = sqrt(n)/2
blist = [b_n.subs(n,i) for i in range(1,101)]
index = [i for i in range(1,101)]
plt.plot(alist,'ro',blist,'bo')                 # plot alist with red dots and blist with blue dots
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %% [markdown]
# #### cumsum ####
#
# This command can generate list of partial sums
#
# https://urldefense.proofpoint.com/v2/url?u=https-3A__docs.scipy.org_doc_numpy_reference_generated_numpy.cumsum.html&d=DwMFaQ&c=u6LDEWzohnDQ01ySGnxMzg&r=0S5Vp3YJyAl2qMyYOYqVE-tUOvBz75Wirkf-T3iD8UU&m=8y9Tl5OKZ4VaYViUEvDW0squ0wP1w6fkjykKfN5QA6U&s=ZvjzYhqTqn-2pj4IgHRlHki5cRJkFEvK5I3nt2wBPCQ&e=

# %%
from numpy import cumsum
n = symbols('n')
a_n = ln(n)
alist = [a_n.subs(n,i).evalf() for i in range(1,11)]
partialsum = cumsum(alist)
print(partialsum)
# Out:
# [0 0.693147180559945 1.79175946922805 3.17805383034795 4.78749174278205
#  6.57925121201010 8.52516136106541 10.6046029027453 12.8018274800815
#  15.1044125730755]

# %% [markdown]
# #### summation ####
#
# This command can calculate the sum of a sequence, especially the infinite sum.

# %%
n = symbols('n')
a_n = 1/2**n
print(summation(a_n,(n,1,oo)))  # calculate the sum of a_n from n=1 to n=oo
# Out:
# 1
